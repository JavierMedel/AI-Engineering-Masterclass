# %% [markdown]
# # Load Environment

# %%
from dotenv import load_dotenv

import os

# %%
load_dotenv("C:/Users/alien51/Documents/AI-Engineer/AI-Engineering-Bootcamp/.env")
# Out:
# True

# %% [markdown]
# ### OpenAI Client

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# aurora brisk shadow kettle mango velvet parrot canyon lantern ripple

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=533, prompt_tokens=24, total_tokens=557, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=512, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="minimal"
)

print(response.choices[0].message.content)
# Out:
# Here are 10 random words:
#
# 1. Meadow
# 2. Lantern
# 3. Quantum
# 4. Velvet
# 5. Nimbus
# 6. Ponder
# 7. Sparrow
# 8. Ember
# 9. Fragment
# 10. Drift

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=56, prompt_tokens=24, total_tokens=80, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="low"
)

print(response.choices[0].message.content)
# Out:
# aurora, marigold, gossamer, quibble, atoll, zephyr, labyrinth, vermilion, juniper, islet

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=168, prompt_tokens=24, total_tokens=192, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=128, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
### Google genAI Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant",
              "can you print 15 random words?"]
)

print(response.text)
# Out:
# Here are 15 random words for you:
#
# 1.  Flutter
# 2.  Glimmer
# 3.  Whistle
# 4.  Jubilant
# 5.  Serene
# 6.  Ephemeral
# 7.  Cascade
# 8.  Luminous
# 9.  Quiver
# 10. Zephyr
# 11. Whisper
# 12. Ripple
# 13. Verdant
# 14. Shimmer
# 15. Murmur
